# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from bs4 import BeautifulSoup
import re
# %matplotlib inline

# %%
df = pd.read_csv('data/old/stock_data.csv')
df
# Out:
#              time      open      high       low     close      Volume  \
# 0      1609459200  0.004683  0.004702  0.004616  0.004702   1865676.0
# 1      1609462800  0.004705  0.004766  0.004701  0.004727   1082226.0
# 2      1609466400  0.004733  0.004765  0.004733  0.004765     85161.0
# 3      1609470000  0.004754  0.005001  0.004754  0.004976   5030766.0
# 4      1609473600  0.005000  0.005001  0.004816  0.004917   5531754.0
# ...           ...       ...       ...       ...       ...         ...
# 16870  1670241600  0.106720  0.106760  0.105800  0.105930  14095010.0
# 16871  1670245200  0.105920  0.106220  0.104040  0.104490  32317575.0
# 16872  1670248800  0.104490  0.104810  0.104050  0.104560  28471456.0
# 16873  1670252400  0.104560  0.104560  0.102000  0.102980  83304122.0
# 16874  1670256000  0.103000  0.103000  0.102760  0.102990   5486500.0
#
#          Volume MA        RSI         CCI       Plot     Plot.1
# 0              NaN        NaN         NaN        NaN        NaN
# 1              NaN        NaN         NaN        NaN        NaN
# 2              NaN        NaN         NaN        NaN        NaN
# 3              NaN        NaN         NaN        NaN        NaN
# 4              NaN        NaN         NaN        NaN        NaN
# ...            ...        ...         ...        ...        ...
# 16870  33668016.40  56.656069   67.917784  15.987122  19.185252
# 16871  34485251.20  49.487025  -21.792511  13.965515  18.989910
# 16872  34507188.55  49.819432  -20.774315  13.947687  18.886065
# 16873  37513687.60  42.949268 -113.742046   6.001206  18.434064
# 16874  36451612.80  43.002841 -107.473012   3.321702  17.918086
#
# [16875 rows x 11 columns]

# %%
#transform to twetts timezone -700
df['time'] = pd.to_datetime(df['time'],unit='s').dt.tz_localize('UTC').dt.tz_convert('Us/Mountain')
df.head()
# Out:
#                        time      open      high       low     close  \
# 0 2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  0.004702
# 1 2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  0.004727
# 2 2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733  0.004765
# 3 2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  0.004976
# 4 2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  0.004917
#
#       Volume  Volume MA  RSI  CCI  Plot  Plot.1
# 0  1865676.0        NaN  NaN  NaN   NaN     NaN
# 1  1082226.0        NaN  NaN  NaN   NaN     NaN
# 2    85161.0        NaN  NaN  NaN   NaN     NaN
# 3  5030766.0        NaN  NaN  NaN   NaN     NaN
# 4  5531754.0        NaN  NaN  NaN   NaN     NaN

# %%
df_todrop = df.iloc[:,[0,1,2,3,4,5]]
df_todrop.head()
# Out:
#                        time      open      high       low     close     Volume
# 0 2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  0.004702  1865676.0
# 1 2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  0.004727  1082226.0
# 2 2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733  0.004765    85161.0
# 3 2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  0.004976  5030766.0
# 4 2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  0.004917  5531754.0

# %%
df_todrop['percent'] = ''
df_todrop.head()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_44824\1888032433.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_todrop['percent'] = ''
#                        time      open      high       low     close  \
# 0 2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  0.004702
# 1 2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  0.004727
# 2 2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733  0.004765
# 3 2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  0.004976
# 4 2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  0.004917
#
#       Volume percent
# 0  1865676.0
# 1  1082226.0
# 2    85161.0
# 3  5030766.0
# 4  5531754.0

# %%
df_todrop['value'] = df_todrop['close'] - df_todrop['open']
df_todrop['percent'] = ((df_todrop['close'] - df_todrop['open'])/df_todrop['open']) * 100
df_todrop['percent'] = df_todrop['percent'].round(2)
df_todrop.head()
# Out:
# C:\Users\andre\AppData\Local\Temp\ipykernel_44824\821773560.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_todrop['value'] = df_todrop['close'] - df_todrop['open']
# C:\Users\andre\AppData\Local\Temp\ipykernel_44824\821773560.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_todrop['percent'] = ((df_todrop['close'] - df_todrop['open'])/df_todrop['open']) * 100
# C:\Users\andre\AppData\Local\Temp\ipykernel_44824\821773560.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_todrop['percent'] = df_todrop['percent'].round(2)
#                        time      open      high       low     close  \
# 0 2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  0.004702
# 1 2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  0.004727
# 2 2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733  0.004765
# 3 2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  0.004976
# 4 2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  0.004917
#
#       Volume  percent     value
# 0  1865676.0     0.41  0.000019
# 1  1082226.0     0.47  0.000022
# 2    85161.0     0.68  0.000032
# 3  5030766.0     4.67  0.000222
# 4  5531754.0    -1.66 -0.000083

# %%
plt.plot(df_todrop['percent'])

# %%
df_todrop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16875 entries, 0 to 16874
# Data columns (total 8 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   time     16875 non-null  datetime64[ns, US/Mountain]
#  1   open     16875 non-null  float64
#  2   high     16875 non-null  float64
#  3   low      16875 non-null  float64
#  4   close    16875 non-null  float64
#  5   Volume   16875 non-null  float64
#  6   percent  16875 non-null  float64
#  7   value    16875 non-null  float64
# dtypes: datetime64[ns, US/Mountain](1), float64(7)
# memory usage: 1.0 MB

# %%
sns.boxplot(x=df_todrop['percent'])
# Out:
# <AxesSubplot:xlabel='percent'>

# %%
sns.histplot(x=df_todrop['percent'])
# Out:
# <AxesSubplot:xlabel='percent', ylabel='Count'>

# %%
df_try = df_todrop.copy()
df_try
# Out:
#                            time      open      high       low     close  \
# 0     2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  0.004702
# 1     2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  0.004727
# 2     2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733  0.004765
# 3     2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  0.004976
# 4     2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  0.004917
# ...                         ...       ...       ...       ...       ...
# 16870 2022-12-05 05:00:00-07:00  0.106720  0.106760  0.105800  0.105930
# 16871 2022-12-05 06:00:00-07:00  0.105920  0.106220  0.104040  0.104490
# 16872 2022-12-05 07:00:00-07:00  0.104490  0.104810  0.104050  0.104560
# 16873 2022-12-05 08:00:00-07:00  0.104560  0.104560  0.102000  0.102980
# 16874 2022-12-05 09:00:00-07:00  0.103000  0.103000  0.102760  0.102990
#
#            Volume  percent     value
# 0       1865676.0     0.41  0.000019
# 1       1082226.0     0.47  0.000022
# 2         85161.0     0.68  0.000032
# 3       5030766.0     4.67  0.000222
# 4       5531754.0    -1.66 -0.000083
# ...           ...      ...       ...
# 16870  14095010.0    -0.74 -0.000790
# 16871  32317575.0    -1.35 -0.001430
# 16872  28471456.0     0.07  0.000070
# 16873  83304122.0    -1.51 -0.001580
# 16874   5486500.0    -0.01 -0.000010
#
# [16875 rows x 8 columns]

# %%
#df_try['tv'] = ''
#df_try['tv'].value_counts()
#df_try.head()
#df_try.shape
#df_try.info()
# Out:
#     16875
# Name: tv, dtype: int64

# %%
df_try['tv']=df_try['percent'].apply(lambda x: '-1' if x<=-0.3 
                                     else '0' if x>-0.3 and x<0.3 
                                     else '1')

# %%
sns.histplot(x=df_try['tv'])
# Out:
# <AxesSubplot:xlabel='tv', ylabel='Count'>

# %%
df_try.head()
# Out:
#                        time      open      high       low     close  \
# 0 2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  0.004702
# 1 2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  0.004727
# 2 2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733  0.004765
# 3 2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  0.004976
# 4 2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  0.004917
#
#       Volume  percent     value  tv
# 0  1865676.0     0.41  0.000019   1
# 1  1082226.0     0.47  0.000022   1
# 2    85161.0     0.68  0.000032   1
# 3  5030766.0     4.67  0.000222   1
# 4  5531754.0    -1.66 -0.000083  -1

# %%
df_tomodel = df_try.drop(['close', 'percent', 'value'], axis=1)
df_tomodel.head()
# Out:
#                        time      open      high       low     Volume  tv
# 0 2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616  1865676.0   1
# 1 2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701  1082226.0   1
# 2 2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733    85161.0   1
# 3 2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754  5030766.0   1
# 4 2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816  5531754.0  -1

# %%
df_tomodel['tv'].value_counts()
# Out:
# -1    5956
#  1    5880
#  0    5039
# Name: tv, dtype: int64

# %%
#CHOOSING DATES (optional)
#df_orudates = df1.copy()
#df_orudates = df_orudates[(df_orudates['time'] > '2021-01-01') & (df_orudates['time'] < '2021-04-30')]
#df_orudates.head(50)

# %%
df_tomodel.to_csv('data/dataprices012.csv', index=False)

# %%
#Check
df12 = pd.read_csv('data/dataprices012.csv')
df12
# Out:
#                             time      open      high       low      Volume  tv
# 0      2020-12-31 17:00:00-07:00  0.004683  0.004702  0.004616   1865676.0   1
# 1      2020-12-31 18:00:00-07:00  0.004705  0.004766  0.004701   1082226.0   1
# 2      2020-12-31 19:00:00-07:00  0.004733  0.004765  0.004733     85161.0   1
# 3      2020-12-31 20:00:00-07:00  0.004754  0.005001  0.004754   5030766.0   1
# 4      2020-12-31 21:00:00-07:00  0.005000  0.005001  0.004816   5531754.0  -1
# ...                          ...       ...       ...       ...         ...  ..
# 16870  2022-12-05 05:00:00-07:00  0.106720  0.106760  0.105800  14095010.0  -1
# 16871  2022-12-05 06:00:00-07:00  0.105920  0.106220  0.104040  32317575.0  -1
# 16872  2022-12-05 07:00:00-07:00  0.104490  0.104810  0.104050  28471456.0   0
# 16873  2022-12-05 08:00:00-07:00  0.104560  0.104560  0.102000  83304122.0  -1
# 16874  2022-12-05 09:00:00-07:00  0.103000  0.103000  0.102760   5486500.0   0
#
# [16875 rows x 6 columns]
